# %%
import pandas as pd

# %% [markdown]
# ## ETL data polusi dari Open data Jakarta

# %% [markdown]
# ### Tahun 2021

# %% [markdown]
# ### Januari

# %%
df_januari = pd.read_csv('/home/yann/Documents/MSIB/Data Engineering Academy/8. Final Project/data/open_data_jakarta/indeks-standar-pencemar-udara-di-spku-bulan-januari-tahun-2021.csv')
df_januari.sample(10)
# Out:
#         tanggal                           stasiun pm10 pm25  so2  co  o3 no2  \
# 58   2021-01-28              DKI2 (Kelapa Gading)   28   49   25  10  53   7
# 1    2021-01-02                DKI1 (Bunderan HI)   27   46   27   7  47   7
# 148  2021-01-25  DKI5 (Kebon Jeruk) Jakarta Barat   55  NaN   19  29  67  13
# 44   2021-01-14              DKI2 (Kelapa Gading)   28   49   11   6  65  11
# 90   2021-01-29                  DKI3 (Jagakarsa)   28   16   17   9  48   4
# 46   2021-01-16              DKI2 (Kelapa Gading)   49   71   13  10  67   9
# 2    2021-01-03                DKI1 (Bunderan HI)   44   58   25   7  40  13
# 140  2021-01-17  DKI5 (Kebon Jeruk) Jakarta Barat  ---  NaN   20  15  32   9
# 35   2021-01-05              DKI2 (Kelapa Gading)   35   52  ---   8  77   7
# 51   2021-01-21              DKI2 (Kelapa Gading)   46   44   12   9  67  13
#
#      max critical categori
# 58    53       O3   SEDANG
# 1     47       O3     BAIK
# 148   67       CO   SEDANG
# ...

# %% [markdown]
# ##### Mencari nilai missing

# %%
df_januari.isna().sum()
# Out:
# tanggal      0
# stasiun      0
# pm10         0
# pm25        62
# so2          0
# co           0
# o3           0
# no2          0
# max          0
# critical     2
# categori     0
# dtype: int64

# %%
df_januari.dropna(inplace=True)

# %%
df_januari.isna().sum()
# Out:
# tanggal     0
# stasiun     0
# pm10        0
# pm25        0
# so2         0
# co          0
# o3          0
# no2         0
# max         0
# critical    0
# categori    0
# dtype: int64

# %% [markdown]
# ##### Memformat tipe data

# %%
df_januari.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 93 entries, 0 to 92
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tanggal   93 non-null     object
#  1   stasiun   93 non-null     object
#  2   pm10      93 non-null     object
#  3   pm25      93 non-null     object
#  4   so2       93 non-null     object
#  5   co        93 non-null     object
#  6   o3        93 non-null     object
#  7   no2       93 non-null     object
#  8   max       93 non-null     int64
#  9   critical  93 non-null     object
#  10  categori  93 non-null     object
# dtypes: int64(1), object(10)
# memory usage: 8.7+ KB

# %%
df_januari.head()
# Out:
#       tanggal             stasiun pm10 pm25 so2 co  o3 no2  max critical  \
# 0  2021-01-01  DKI1 (Bunderan HI)   38   53  29  6  31  13   53     PM25
# 1  2021-01-02  DKI1 (Bunderan HI)   27   46  27  7  47   7   47       O3
# 2  2021-01-03  DKI1 (Bunderan HI)   44   58  25  7  40  13   58     PM25
# 3  2021-01-04  DKI1 (Bunderan HI)   30   48  24  4  32   7   48     PM25
# 4  2021-01-05  DKI1 (Bunderan HI)   38   53  24  6  31   9   53     PM25
#
#   categori
# 0   SEDANG
# 1     BAIK
# 2   SEDANG
# 3     BAIK
# 4   SEDANG

# %%
# format data tanggal
df_januari['tanggal'].head()
# Out:
# 0    2021-01-01
# 1    2021-01-02
# 2    2021-01-03
# 3    2021-01-04
# 4    2021-01-05
# Name: tanggal, dtype: object

# %%
df_januari['tanggal'] = pd.to_datetime(df_januari['tanggal'])
df_januari['tanggal']
# Out:
# 0    2021-01-01
# 1    2021-01-02
# 2    2021-01-03
# 3    2021-01-04
# 4    2021-01-05
#         ...
# 88   2021-01-27
# 89   2021-01-28
# 90   2021-01-29
# 91   2021-01-30
# 92   2021-01-31
# Name: tanggal, Length: 93, dtype: datetime64[ns]

# %%
df_januari[60:94]
# Out:
#       tanggal               stasiun pm10 pm25 so2  co  o3  no2  max critical  \
# 60 2021-01-30  DKI2 (Kelapa Gading)   27   39  25  10  64    8   64       O3
# 61 2021-01-31  DKI2 (Kelapa Gading)   38   55  24  11  68    7   68       O3
# 62 2021-01-01      DKI3 (Jagakarsa)   43   56  15  10  33    5   56     PM25
# 63 2021-01-02      DKI3 (Jagakarsa)   58   86  15  22  38    5   86     PM25
# 64 2021-01-03      DKI3 (Jagakarsa)   64   93  14  20  35    5   93     PM25
# 65 2021-01-04      DKI3 (Jagakarsa)   50   67  13  15  17    4   67     PM25
# 66 2021-01-05      DKI3 (Jagakarsa)   59   89  15  19  42    7   89     PM25
# 67 2021-01-06      DKI3 (Jagakarsa)   52   81  18  28  52   11   81     PM25
# 68 2021-01-07      DKI3 (Jagakarsa)   22   52  16  12  44    5   52     PM25
# 69 2021-01-08      DKI3 (Jagakarsa)   26   68  21  22  40    9   68     PM25
# 70 2021-01-09      DKI3 (Jagakarsa)   25   77  17  32  31    8   77     PM25
# ...

# %%
# pm10
df_januari[df_januari['pm10'] == '---']
df_januari.drop([72,73], inplace=True)

# %%
# pm25
df_januari[df_januari['pm25'] == '---']
df_januari.drop([81,82], inplace=True)

# %%
# so2
df_januari[df_januari['so2'] == '---']
df_januari.drop(range(32,39), inplace=True)

# %%
# no2
df_januari[df_januari['no2'] == '---']
df_januari.drop(92, inplace=True)

# %%
# Memformat tipe data (pm10, pm25, so2, co, o3, no2)
df_januari['pm10'] = df_januari['pm10'].astype(int)
df_januari['pm25'] = df_januari['pm25'].astype(int)
df_januari['so2'] = df_januari['so2'].astype(int)
df_januari['co'] = df_januari['co'].astype(int)
df_januari['o3'] = df_januari['o3'].astype(int)
df_januari['no2'] = df_januari['no2'].astype(int)

# %%
df_januari.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81 entries, 0 to 91
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tanggal   81 non-null     datetime64[ns]
#  1   stasiun   81 non-null     object
#  2   pm10      81 non-null     int64
#  3   pm25      81 non-null     int64
#  4   so2       81 non-null     int64
#  5   co        81 non-null     int64
#  6   o3        81 non-null     int64
#  7   no2       81 non-null     int64
#  8   max       81 non-null     int64
#  9   critical  81 non-null     object
#  10  categori  81 non-null     object
# dtypes: datetime64[ns](1), int64(7), object(3)
# memory usage: 7.6+ KB

# %% [markdown]
# #### Duplikasi Data

# %%
df_januari[df_januari.duplicated(['tanggal','stasiun'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [tanggal, stasiun, pm10, pm25, so2, co, o3, no2, max, critical, categori]
# Index: []

# %% [markdown]
# ### Februari

# %%
df_februari = pd.read_csv('/home/yann/Documents/MSIB/Data Engineering Academy/8. Final Project/data/open_data_jakarta/indeks-standar-pencemar-udara-di-spku-bulan-februari-tahun-2021.csv')
df_februari.head()
# Out:
#       tanggal             stasiun pm10 pm25 so2  co  o3 no2  max critical  \
# 0  2021-02-01  DKI1 (Bunderan HI)   59   79  21  26  15  31   79     PM25
# 1  2021-02-02  DKI1 (Bunderan HI)   30   46  21  14  16  24   46     PM25
# 2  2021-02-03  DKI1 (Bunderan HI)   23   33  19  11  14  19   33     PM25
# 3  2021-02-04  DKI1 (Bunderan HI)   36   53  23  14  12  24   53     PM25
# 4  2021-02-05  DKI1 (Bunderan HI)   29   36  20  14  12  21   36     PM25
#
#   categori
# 0   SEDANG
# 1     BAIK
# 2     BAIK
# 3   SEDANG
# 4     BAIK

# %% [markdown]
# #### Mencari missing value

# %%
df_februari.isna().sum()
# Out:
# tanggal     0
# stasiun     0
# pm10        0
# pm25        0
# so2         0
# co          0
# o3          0
# no2         0
# max         0
# critical    2
# categori    0
# dtype: int64

# %%
df_februari.dropna(inplace=True)

# %%
df_februari.shape
# Out:
# (138, 11)

# %%
df_februari[df_februari['pm10'] == '---']
df_februari[df_februari['co'] == '---']
df_februari[df_februari['o3'] == '---']
# Out:
#        tanggal               stasiun pm10 pm25 so2  co   o3 no2  max critical  \
# 53  2021-02-26  DKI2 (Kelapa Gading)   45   54  43  13  ---  19   54     PM25
#
#    categori
# 53   SEDANG

# %%
df_februari.drop([113,116,117,118,119,120,33,34,35,53], inplace=True)

# %%
df_februari.sample(20)
# Out:
#         tanggal                           stasiun pm10 pm25 so2  co  o3 no2  \
# 111  2021-02-28               DKI4 (Lubang Buaya)   68  113  39  18  24  14
# 114  2021-02-03  DKI5 (Kebon Jeruk) Jakarta Barat   23   40  27   5  16  10
# 128  2021-02-17  DKI5 (Kebon Jeruk) Jakarta Barat   44   71  33  25  14  37
# 65   2021-02-10                  DKI3 (Jagakarsa)   50   64  24  11  23  10
# 68   2021-02-13                  DKI3 (Jagakarsa)   59   89  26  12  30  13
# 104  2021-02-21               DKI4 (Lubang Buaya)   21   50  39  10  23  10
# 30   2021-02-03              DKI2 (Kelapa Gading)   24   35  38   4  42  15
# 4    2021-02-05                DKI1 (Bunderan HI)   29   36  20  14  12  21
# 133  2021-02-22  DKI5 (Kebon Jeruk) Jakarta Barat   56   92  25  20  16  40
# 110  2021-02-27               DKI4 (Lubang Buaya)   59   94  40  13  30  12
# 139  2021-02-28  DKI5 (Kebon Jeruk) Jakarta Barat   50   77  22   9  22  13
# ...

# %% [markdown]
# #### Memformat tipe data

# %%
df_februari.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 128 entries, 0 to 139
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tanggal   128 non-null    object
#  1   stasiun   128 non-null    object
#  2   pm10      128 non-null    object
#  3   pm25      128 non-null    object
#  4   so2       128 non-null    object
#  5   co        128 non-null    object
#  6   o3        128 non-null    object
#  7   no2       128 non-null    object
#  8   max       128 non-null    int64
#  9   critical  128 non-null    object
#  10  categori  128 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 12.0+ KB

# %%
df_februari['tanggal'] = pd.to_datetime(df_februari['tanggal'])

# %%
df_februari = df_februari.astype({'pm10':int, 'pm25':int, 'so2':int, 'co':int, 'o3':int, 'no2':int})

# %% [markdown]
# #### Duplikasi data

# %%
df_februari[df_februari.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tanggal, stasiun, pm10, pm25, so2, co, o3, no2, max, critical, categori]
# Index: []

# %% [markdown]
# ### Maret

# %%
df_maret = pd.read_csv('/home/yann/Documents/MSIB/Data Engineering Academy/8. Final Project/data/open_data_jakarta/indeks-standar-pencemar-udara-di-spku-bulan-maret-tahun-2021.csv')
df_maret.sample(20)
# Out:
#         tanggal                           stasiun pm10 pm25 so2  co  o3 no2  \
# 14   2021-03-15                DKI1 (Bunderan HI)   45   70  29  18  13  34
# 41   2021-03-11              DKI2 (Kelapa Gading)   38   50  26   9  43   9
# 4    2021-03-05                DKI1 (Bunderan HI)   52   69  20  16  16  30
# 89   2021-03-28                  DKI3 (Jagakarsa)   47   63  27  10  43  17
# 92   2021-03-31                  DKI3 (Jagakarsa)   56   22  12  18  32  25
# 48   2021-03-18              DKI2 (Kelapa Gading)   78  115  43  14  74  23
# 151  2021-03-28  DKI5 (Kebon Jeruk) Jakarta Barat   50   78  22  12  34  19
# 154  2021-03-31  DKI5 (Kebon Jeruk) Jakarta Barat   40   62  25   7  16  15
# 54   2021-03-24              DKI2 (Kelapa Gading)   33   57  27  11  37   8
# 124  2021-03-01  DKI5 (Kebon Jeruk) Jakarta Barat   29   60  23   7  16  12
# 107  2021-03-15               DKI4 (Lubang Buaya)   37   77  42  14  24  12
# ...

# %% [markdown]
# #### Missing Value

# %%
df_maret.isna().sum()
# Out:
# tanggal     0
# stasiun     0
# pm10        0
# pm25        0
# so2         0
# co          0
# o3          0
# no2         0
# max         0
# critical    1
# categori    0
# dtype: int64

# %%
df_maret.dropna(inplace=True)

# %%
df_maret[df_maret['pm10'] == '---']
df_maret[df_maret['pm25'] == '---']
# Out:
#        tanggal              stasiun pm10 pm25 so2  co  o3 no2  max critical  \
# 95  2021-03-03  DKI4 (Lubang Buaya)   52  ---  41  19  31  14   52     PM10
#
#    categori
# 95   SEDANG

# %%
df_maret.drop([134,135,95], inplace=True)

# %% [markdown]
# #### Memformat tipe data

# %%
df_maret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, 0 to 154
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tanggal   151 non-null    object
#  1   stasiun   151 non-null    object
#  2   pm10      151 non-null    object
#  3   pm25      151 non-null    object
#  4   so2       151 non-null    object
#  5   co        151 non-null    object
#  6   o3        151 non-null    object
#  7   no2       151 non-null    object
#  8   max       151 non-null    int64
#  9   critical  151 non-null    object
#  10  categori  151 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 14.2+ KB

# %%
df_maret['tanggal'] = pd.to_datetime(df_maret['tanggal'])

# %%
df_maret = df_maret.astype({'pm10':int, 'pm25':int, 'so2':int, 'co':int, 'o3':int, 'no2':int})

# %% [markdown]
# #### Duplikat data

# %%
df_maret[df_maret.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tanggal, stasiun, pm10, pm25, so2, co, o3, no2, max, critical, categori]
# Index: []

# %% [markdown]
# ### April

# %%
df_april = pd.read_csv('/home/yann/Documents/MSIB/Data Engineering Academy/8. Final Project/data/open_data_jakarta/indeks-standar-pencemar-udara-di-spku-bulan-april-tahun-2021.csv')
df_april.sample(20)
# Out:
#         tanggal                           stasiun pm10 pm25  so2   co   o3  \
# 128  2021-04-09  DKI5 (Kebon Jeruk) Jakarta Barat   52   77   34    7   18
# 66   2021-04-07                  DKI3 (Jagakarsa)   25   35   27    3  ---
# 46   2021-04-17              DKI2 (Kelapa Gading)  ---  ---  ---  ---  ---
# 68   2021-04-09                  DKI3 (Jagakarsa)   55   76   26    8  ---
# 86   2021-04-27                  DKI3 (Jagakarsa)   64  104   13    9   34
# 81   2021-04-22                  DKI3 (Jagakarsa)   57   83   20    8   39
# 118  2021-04-29               DKI4 (Lubang Buaya)   51   78   37   12   23
# 58   2021-04-29              DKI2 (Kelapa Gading)   69   85   60   15   44
# 75   2021-04-16                  DKI3 (Jagakarsa)   52   72   27   14   32
# 38   2021-04-09              DKI2 (Kelapa Gading)   53   64   32   10   49
# 107  2021-04-18               DKI4 (Lubang Buaya)   57   82   42   16  ---
# ...

# %% [markdown]
# #### Missing Value

# %%
df_april.isna().sum()
# Out:
# tanggal     0
# stasiun     0
# pm10        0
# pm25        0
# so2         0
# co          0
# o3          0
# no2         0
# max         0
# critical    2
# categori    0
# dtype: int64

# %%
df_april.dropna(inplace=True)

# %%
df_april[df_april['pm10'] == '---']
# Out:
#        tanggal               stasiun pm10 pm25 so2   co   o3 no2  max  \
# 48  2021-04-19  DKI2 (Kelapa Gading)  ---  107  52  ---   41  22  107
# 71  2021-04-12      DKI3 (Jagakarsa)  ---   69  27   15  ---  16   69
# 78  2021-04-19      DKI3 (Jagakarsa)  ---   92  22    9   36  18   92
#
#    critical     categori
# 48     PM25  TIDAK SEHAT
# 71     PM25       SEDANG
# 78     PM25       SEDANG

# %%
df_april = df_april.replace('---', pd.NA)
df_april.dropna(inplace=True)

# %% [markdown]
# #### Format tipe data

# %%
df_april.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 128 entries, 0 to 149
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tanggal   128 non-null    object
#  1   stasiun   128 non-null    object
#  2   pm10      128 non-null    object
#  3   pm25      128 non-null    object
#  4   so2       128 non-null    object
#  5   co        128 non-null    object
#  6   o3        128 non-null    object
#  7   no2       128 non-null    object
#  8   max       128 non-null    int64
#  9   critical  128 non-null    object
#  10  categori  128 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 12.0+ KB

# %%
df_april['tanggal'] = pd.to_datetime(df_april['tanggal'])

# %%
df_april = df_april.astype({'pm10':int, 'pm25':int, 'so2':int, 'co':int, 'o3':int, 'no2':int})

# %% [markdown]
# #### Duplikat data

# %%
df_april[df_april.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tanggal, stasiun, pm10, pm25, so2, co, o3, no2, max, critical, categori]
# Index: []

# %% [markdown]
# ### Mei

# %%
df_mei = pd.read_csv('/home/yann/Documents/MSIB/Data Engineering Academy/8. Final Project/data/open_data_jakarta/indeks-standar-pencemar-udara-di-spku-bulan-mei-tahun-2021.csv')
df_mei.sample(20)
# Out:
#         tanggal                           stasiun pm10 pm25  so2   co   o3  \
# 91   2021-05-30                  DKI3 (Jagakarsa)   44   24   45    9  ---
# 77   2021-05-16                  DKI3 (Jagakarsa)  ---   68   18    7   29
# 20   2021-05-21                DKI1 (Bunderan HI)   52   76   24   15   22
# 4    2021-05-05                DKI1 (Bunderan HI)   58   82   22   18   14
# 62   2021-05-01                  DKI3 (Jagakarsa)   66  102   13   15  ---
# 10   2021-05-11                DKI1 (Bunderan HI)   60   88   24   12   25
# 131  2021-05-08  DKI5 (Kebon Jeruk) Jakarta Barat   43   74   21    8   30
# 128  2021-05-05  DKI5 (Kebon Jeruk) Jakarta Barat   54   90   25   14   21
# 14   2021-05-15                DKI1 (Bunderan HI)   51   67   26   11   20
# 69   2021-05-08                  DKI3 (Jagakarsa)   50   76   20    8   71
# 87   2021-05-26                  DKI3 (Jagakarsa)   58   82   47    8   29
# ...

# %% [markdown]
# #### Missing value

# %%
df_mei.isna().sum()
# Out:
# tanggal     0
# stasiun     0
# pm10        0
# pm25        0
# so2         0
# co          0
# o3          0
# no2         0
# max         0
# critical    0
# categori    0
# dtype: int64

# %%
df_mei = df_mei.replace('---', pd.NA)
df_mei.dropna(inplace=True)

# %% [markdown]
# #### Format Tipe data

# %%
df_mei.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 127 entries, 0 to 154
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tanggal   127 non-null    object
#  1   stasiun   127 non-null    object
#  2   pm10      127 non-null    object
#  3   pm25      127 non-null    object
#  4   so2       127 non-null    int64
#  5   co        127 non-null    object
#  6   o3        127 non-null    object
#  7   no2       127 non-null    object
#  8   max       127 non-null    int64
#  9   critical  127 non-null    object
#  10  categori  127 non-null    object
# dtypes: int64(2), object(9)
# memory usage: 11.9+ KB

# %%
df_mei['tanggal'] = pd.to_datetime(df_mei['tanggal'])

# %%
df_mei = df_mei.astype({'pm10':int, 'pm25':int, 'so2':int, 'co':int, 'o3':int, 'no2':int})

# %% [markdown]
# #### Duplikat data

# %%
df_mei[df_mei.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tanggal, stasiun, pm10, pm25, so2, co, o3, no2, max, critical, categori]
# Index: []

# %% [markdown]
# ### Juni

# %%
df_juni = pd.read_csv('/home/yann/Documents/MSIB/Data Engineering Academy/8. Final Project/data/open_data_jakarta/indeks-standar-pencemar-udara-di-spku-bulan-juni-tahun-2021.csv')
df_juni.sample(20)
# Out:
#         tanggal                              pm10  pm25  so2  co  o3 no2  max  \
# 24   2021-06-25                DKI1 (Bunderan HI)    59   82  36  14  17   32
# 89   2021-06-30                  DKI3 (Jagakarsa)    79   26  49  10  23   19
# 117  2021-06-28               DKI4 (Lubang Buaya)    60  117  36  18  30   22
# 51   2021-06-22              DKI2 (Kelapa Gading)    59   72  54  14  38   27
# 77   2021-06-18                  DKI3 (Jagakarsa)    62   87  48  10  25   21
# 49   2021-06-20              DKI2 (Kelapa Gading)    81  108  66  18  44   35
# 147  2021-06-28  DKI5 (Kebon Jeruk) Jakarta Barat    59   99  25  17  21   30
# 111  2021-06-22               DKI4 (Lubang Buaya)    47   84  33  16  21   22
# 59   2021-06-30              DKI2 (Kelapa Gading)    79  105  57  14  55   28
# 32   2021-06-03              DKI2 (Kelapa Gading)    68   93  57  16  61   32
# 101  2021-06-12               DKI4 (Lubang Buaya)    55   93  27  13  30   24
# ...

# %% [markdown]
# #### Rename columns

# %%
df_juni = df_juni.rename(columns={
    'categori':'critical',
    'location':'categori',
    'pm10':'stasiun',
    'pm25':'pm10',
    'so2':'pm25',
    'co':'so2',
    'o3':'co',
    'no2':'o3',
    'max':'no2',
    'critical':'max'   
})

# %% [markdown]
# #### Missing Value

# %%
df_juni.isna().sum()
# Out:
# tanggal     0
# stasiun     0
# pm10        0
# pm25        0
# so2         0
# co          0
# o3          0
# no2         0
# max         0
# critical    0
# categori    0
# dtype: int64

# %%
df_juni = df_juni.replace('---', pd.NA)
df_juni.dropna(inplace=True)

# %% [markdown]
# #### Format tipe data

# %%
df_juni.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 138 entries, 0 to 149
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tanggal   138 non-null    object
#  1   stasiun   138 non-null    object
#  2   pm10      138 non-null    int64
#  3   pm25      138 non-null    object
#  4   so2       138 non-null    object
#  5   co        138 non-null    object
#  6   o3        138 non-null    object
#  7   no2       138 non-null    int64
#  8   max       138 non-null    int64
#  9   critical  138 non-null    object
#  10  categori  138 non-null    object
# dtypes: int64(3), object(8)
# memory usage: 12.9+ KB

# %%
df_juni = df_juni.astype(str)

# %%
df_juni.head()
# Out:
#       tanggal             stasiun pm10 pm25 so2  co  o3 no2 max critical  \
# 0  2021-06-01  DKI1 (Bunderan HI)   59   83  22  18  19  35  83     PM25
# 1  2021-06-02  DKI1 (Bunderan HI)   59   84  21  20  24  38  84     PM25
# 2  2021-06-03  DKI1 (Bunderan HI)   54   76  22  20  17  41  76     PM25
# 3  2021-06-04  DKI1 (Bunderan HI)   63   87  20  13  14  30  87     PM25
# 4  2021-06-05  DKI1 (Bunderan HI)   59   79  23  20  19  38  79     PM25
#
#   categori
# 0   SEDANG
# 1   SEDANG
# 2   SEDANG
# 3   SEDANG
# 4   SEDANG

# %%
df_juni['tanggal'] = pd.to_datetime(df_juni['tanggal'])

# %%
df_juni = df_juni.astype({'pm10':int, 'pm25':int, 'so2':int, 'co':int, 'o3':int, 'no2':int, 'max':int})

# %% [markdown]
# #### Duplikat Data

# %%
df_juni[df_juni.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tanggal, stasiun, pm10, pm25, so2, co, o3, no2, max, critical, categori]
# Index: []

# %%
# df_juni

# %% [markdown]
# ### Juli

# %%
df_juli = pd.read_csv('/home/yann/Documents/MSIB/Data Engineering Academy/8. Final Project/data/open_data_jakarta/indeks-standar-pencemar-udara-di-spku-bulan-juli-tahun-2021.csv')
df_juli.sample(20)
# Out:
#         tanggal                              pm10 pm25  so2  co  o3 no2 max  \
# 121  2021-07-29               DKI4 (Lubang Buaya)   66  130  40  12  25  25
# 128  2021-07-05  DKI5 (Kebon Jeruk) Jakarta Barat   66  115  35  11  36  20
# 131  2021-07-08  DKI5 (Kebon Jeruk) Jakarta Barat   62  108  37  10  30  23
# 116  2021-07-24               DKI4 (Lubang Buaya)   56  104  37  12  27  25
# 29   2021-07-30                DKI1 (Bunderan HI)   73  105  29  12  39  35
# 153  2021-07-30  DKI5 (Kebon Jeruk) Jakarta Barat   75  121  37  12  50  21
# 93   2021-07-01               DKI4 (Lubang Buaya)   62  114  37  13  23  27
# 99   2021-07-07               DKI4 (Lubang Buaya)   69  130  40  12  26  26
# 103  2021-07-11               DKI4 (Lubang Buaya)   66  119  39  10  21  17
# 129  2021-07-06  DKI5 (Kebon Jeruk) Jakarta Barat   52   80  32   8  32  23
# 44   2021-07-14              DKI2 (Kelapa Gading)   56   75  51  12  50  23
# ...

# %% [markdown]
# #### Rename

# %%
df_juli = df_juli.rename(columns={
    'categori':'critical',
    'location':'categori',
    'pm10':'stasiun',
    'pm25':'pm10',
    'so2':'pm25',
    'co':'so2',
    'o3':'co',
    'no2':'o3',
    'max':'no2',
    'critical':'max'   
})

# %% [markdown]
# #### Missing Value

# %%
df_juli.isna().sum()
# Out:
# tanggal     0
# stasiun     0
# pm10        0
# pm25        0
# so2         0
# co          0
# o3          0
# no2         0
# max         0
# critical    1
# categori    0
# dtype: int64

# %%
df_juli = df_juli.replace('---', pd.NA)
df_juli.dropna(inplace=True)

# %% [markdown]
# #### Format tipe data

# %%
df_juli.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 149 entries, 0 to 154
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tanggal   149 non-null    object
#  1   stasiun   149 non-null    object
#  2   pm10      149 non-null    object
#  3   pm25      149 non-null    object
#  4   so2       149 non-null    object
#  5   co        149 non-null    object
#  6   o3        149 non-null    object
#  7   no2       149 non-null    object
#  8   max       149 non-null    int64
#  9   critical  149 non-null    object
#  10  categori  149 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 14.0+ KB

# %%
df_juli['tanggal'] = pd.to_datetime(df_juli['tanggal'])

# %%
df_juli = df_juli.astype({'pm10':int, 'pm25':int, 'so2':int, 'co':int, 'o3':int, 'no2':int, 'max':int})

# %% [markdown]
# #### Duplikat Data

# %%
df_juli[df_juli.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tanggal, stasiun, pm10, pm25, so2, co, o3, no2, max, critical, categori]
# Index: []

# %%
df_juli
# Out:
#        tanggal                           stasiun  pm10  pm25  so2  co  o3  \
# 0   2021-07-01                DKI1 (Bunderan HI)    55    76   27  14  20
# 1   2021-07-02                DKI1 (Bunderan HI)    55    70   33  16  14
# 2   2021-07-03                DKI1 (Bunderan HI)    58    81   33  12  19
# 3   2021-07-04                DKI1 (Bunderan HI)    68   102   27  11  27
# 4   2021-07-05                DKI1 (Bunderan HI)    71   106   28  12  34
# ..         ...                               ...   ...   ...  ...  ..  ..
# 150 2021-07-27  DKI5 (Kebon Jeruk) Jakarta Barat    64   110   32  13  29
# 151 2021-07-28  DKI5 (Kebon Jeruk) Jakarta Barat    70   130   33  17  28
# 152 2021-07-29  DKI5 (Kebon Jeruk) Jakarta Barat    78   140   32  18  29
# 153 2021-07-30  DKI5 (Kebon Jeruk) Jakarta Barat    75   121   37  12  50
# 154 2021-07-31  DKI5 (Kebon Jeruk) Jakarta Barat    53    80   29   6  34
#
#      no2  max critical     categori
# 0     31   76     PM25       SEDANG
# ...

# %% [markdown]
# ### Agustus

# %%
df_agustus = pd.read_csv('/home/yann/Documents/MSIB/Data Engineering Academy/8. Final Project/data/open_data_jakarta/indeks-standar-pencemar-udara-di-spku-bulan-agustus-tahun-2021.csv')
df_agustus.sample(20)
# Out:
#         tanggal                           stasiun  pm10  pm25  so2  co  o3  \
# 93   2021-08-01               DKI4 (Lubang Buaya)    51    86   39   8  30
# 22   2021-08-23                DKI1 (Bunderan HI)    56    77   28  10  25
# 7    2021-08-08                DKI1 (Bunderan HI)    53    69   33   6  23
# 82   2021-08-21                  DKI3 (Jagakarsa)    53    80   44  10  33
# 17   2021-08-18                DKI1 (Bunderan HI)    59    78   25  11  27
# 150  2021-08-27  DKI5 (Kebon Jeruk) Jakarta Barat    61    96   34   8  29
# 138  2021-08-15  DKI5 (Kebon Jeruk) Jakarta Barat    62    87   33  12  17
# 21   2021-08-22                DKI1 (Bunderan HI)    59    81   28  14  25
# 87   2021-08-26                  DKI3 (Jagakarsa)    54    82   46   9  30
# 151  2021-08-28  DKI5 (Kebon Jeruk) Jakarta Barat    63   100   31   8  44
# 104  2021-08-12               DKI4 (Lubang Buaya)    57   104   40   8  21
# ...

# %% [markdown]
# #### Missing value

# %%
df_agustus.isna().sum()
# Out:
# tanggal     0
# stasiun     0
# pm10        0
# pm25        0
# so2         0
# co          0
# o3          0
# no2         0
# max         0
# critical    0
# categori    0
# dtype: int64

# %%
df_agustus = df_agustus.replace('---', pd.NA)
df_agustus.dropna(inplace=True)

# %% [markdown]
# #### Format tipe data

# %%
df_agustus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tanggal   155 non-null    object
#  1   stasiun   155 non-null    object
#  2   pm10      155 non-null    int64
#  3   pm25      155 non-null    int64
#  4   so2       155 non-null    int64
#  5   co        155 non-null    int64
#  6   o3        155 non-null    int64
#  7   no2       155 non-null    int64
#  8   max       155 non-null    int64
#  9   critical  155 non-null    object
#  10  categori  155 non-null    object
# dtypes: int64(7), object(4)
# memory usage: 13.4+ KB

# %%
df_agustus['tanggal'] = pd.to_datetime(df_agustus['tanggal'])

# %%
df_agustus = df_agustus.astype({'pm10':int, 'pm25':int, 'so2':int, 'co':int, 'o3':int, 'no2':int, 'max':int})

# %% [markdown]
# #### Duplikat Data

# %%
df_agustus[df_agustus.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tanggal, stasiun, pm10, pm25, so2, co, o3, no2, max, critical, categori]
# Index: []

# %% [markdown]
# #### September

# %%
df_september = pd.read_csv('/home/yann/Documents/MSIB/Data Engineering Academy/8. Final Project/data/open_data_jakarta/indeks-standar-pencemar-udara-di-spku-bulan-september-tahun-2021.csv')
df_september.sample(20)
# Out:
#         tanggal                           stasiun pm10 pm25  so2  co  o3 no2  \
# 143  2021-09-24  DKI5 (Kebon Jeruk) Jakarta Barat   51   73  ---   6  20  17
# 95   2021-09-06               DKI4 (Lubang Buaya)   62  109   42   9  29  16
# 127  2021-09-08  DKI5 (Kebon Jeruk) Jakarta Barat   51   78  ---   8  28  15
# 125  2021-09-06  DKI5 (Kebon Jeruk) Jakarta Barat   65   95  ---   8  27  13
# 139  2021-09-20  DKI5 (Kebon Jeruk) Jakarta Barat   45   65  ---   5  30  10
# 77   2021-09-18                  DKI3 (Jagakarsa)   55   80   50   9  27  15
# 6    2021-09-07                DKI1 (Bunderan HI)   52   65   28   9  19  24
# 118  2021-09-29               DKI4 (Lubang Buaya)  ---  102   45  13  38  24
# 123  2021-09-04  DKI5 (Kebon Jeruk) Jakarta Barat   58   84  ---   6  37  11
# 26   2021-09-27                DKI1 (Bunderan HI)   51   72   27  12  22  33
# 88   2021-09-29                  DKI3 (Jagakarsa)   61   26   49  13  31  22
# ...

# %% [markdown]
# #### Missing Value

# %%
df_september.isna().sum()
# Out:
# tanggal     0
# stasiun     0
# pm10        0
# pm25        0
# so2         0
# co          0
# o3          0
# no2         0
# max         0
# critical    2
# categori    0
# dtype: int64

# %%
df_september = df_september.replace('---', pd.NA)
df_september.dropna(inplace=True)

# %% [markdown]
# #### Format tipe data

# %%
df_september.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 107 entries, 0 to 122
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tanggal   107 non-null    object
#  1   stasiun   107 non-null    object
#  2   pm10      107 non-null    object
#  3   pm25      107 non-null    object
#  4   so2       107 non-null    object
#  5   co        107 non-null    object
#  6   o3        107 non-null    object
#  7   no2       107 non-null    object
#  8   max       107 non-null    int64
#  9   critical  107 non-null    object
#  10  categori  107 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 10.0+ KB

# %%
df_september['tanggal'] = pd.to_datetime(df_september['tanggal'])

# %%
df_september = df_september.astype({'pm10':int, 'pm25':int, 'so2':int, 'co':int, 'o3':int, 'no2':int, 'max':int})

# %% [markdown]
# #### Duplikat data

# %%
df_september[df_september.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tanggal, stasiun, pm10, pm25, so2, co, o3, no2, max, critical, categori]
# Index: []

# %% [markdown]
# ### Oktober

# %%
df_oktober = pd.read_csv('/home/yann/Documents/MSIB/Data Engineering Academy/8. Final Project/data/open_data_jakarta/indeks-standar-pencemar-udara-di-spku-bulan-oktober-tahun-2021.csv')
df_oktober.sample(20)
# Out:
#         tanggal                           stasiun pm10 pm25  so2  co  o3 no2  \
# 132  2021-10-09  DKI5 (Kebon Jeruk) Jakarta Barat   53   74  ---   7  43  12
# 91   2021-10-30                  DKI3 (Jagakarsa)   48   31   51  12  39  18
# 87   2021-10-26                  DKI3 (Jagakarsa)   51   71   51  13  30  15
# 149  2021-10-26  DKI5 (Kebon Jeruk) Jakarta Barat   58   92  ---  16  29  24
# 11   2021-10-12                DKI1 (Bunderan HI)   56   76   37   9  23  35
# 15   2021-10-16                DKI1 (Bunderan HI)   66   95   28  15  32  44
# 103  2021-10-11               DKI4 (Lubang Buaya)   62  100   43  10  44  26
# 20   2021-10-21                DKI1 (Bunderan HI)   45   65   25   9  28  32
# 144  2021-10-21  DKI5 (Kebon Jeruk) Jakarta Barat   42   70  ---   7  34  14
# 39   2021-10-09              DKI2 (Kelapa Gading)   53   77   62   9  60  19
# 127  2021-10-04  DKI5 (Kebon Jeruk) Jakarta Barat   53   80  ---   7  31  10
# ...

# %% [markdown]
# #### Missing value

# %%
df_oktober.isna().sum()
# Out:
# tanggal     0
# stasiun     0
# pm10        0
# pm25        0
# so2         0
# co          0
# o3          0
# no2         0
# max         0
# critical    2
# categori    0
# dtype: int64

# %%
df_oktober = df_oktober.replace('---', pd.NA)
df_oktober.dropna(inplace=True)

# %% [markdown]
# #### Format tipe data

# %%
df_oktober.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 109 entries, 0 to 122
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tanggal   109 non-null    object
#  1   stasiun   109 non-null    object
#  2   pm10      109 non-null    object
#  3   pm25      109 non-null    object
#  4   so2       109 non-null    object
#  5   co        109 non-null    object
#  6   o3        109 non-null    object
#  7   no2       109 non-null    object
#  8   max       109 non-null    int64
#  9   critical  109 non-null    object
#  10  categori  109 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 10.2+ KB

# %%
df_oktober['tanggal'] = pd.to_datetime(df_oktober['tanggal'])

# %%
df_oktober = df_oktober.astype({'pm10':int, 'pm25':int, 'so2':int, 'co':int, 'o3':int, 'no2':int})

# %% [markdown]
# #### Duplikat data

# %%
df_oktober[df_oktober.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tanggal, stasiun, pm10, pm25, so2, co, o3, no2, max, critical, categori]
# Index: []

# %% [markdown]
# ### November

# %%
df_november = pd.read_csv('/home/yann/Documents/MSIB/Data Engineering Academy/8. Final Project/data/open_data_jakarta/indeks-standar-pencemar-udara-di-spku-bulan-november-tahun-2021.csv')
df_november.sample(20)
# Out:
#         tanggal                           stasiun pm10 pm25  so2  co   o3 no2  \
# 13   2021-11-14                DKI1 (Bunderan HI)   42   53   29  11   18   7
# 17   2021-11-18                DKI1 (Bunderan HI)   55   75   43  18   19  13
# 109  2021-11-20               DKI4 (Lubang Buaya)   26   58   38   6   21  13
# 107  2021-11-18               DKI4 (Lubang Buaya)   63  106   41   9   27  18
# 82   2021-11-23                  DKI3 (Jagakarsa)   24   30   41   3   29   4
# 87   2021-11-28                  DKI3 (Jagakarsa)   16   25   41   4   34   6
# 27   2021-11-28                DKI1 (Bunderan HI)   19   20   29   5   14   4
# 132  2021-11-13  DKI5 (Kebon Jeruk) Jakarta Barat   46   75  ---  14   29  40
# 96   2021-11-07               DKI4 (Lubang Buaya)   52   81   44   9   35  17
# 44   2021-11-15              DKI2 (Kelapa Gading)  ---   57  ---   9   36  17
# 73   2021-11-14                  DKI3 (Jagakarsa)   40   56   47  11  ---  11
# ...

# %% [markdown]
# #### Missing value

# %%
df_november.isna().sum()
# Out:
# tanggal     0
# stasiun     0
# pm10        0
# pm25        0
# so2         0
# co          0
# o3          0
# no2         0
# max         0
# critical    1
# categori    0
# dtype: int64

# %%
df_november = df_november.replace('---', pd.NA)
df_november.dropna(inplace=True)

# %% [markdown]
# #### Format tipe data

# %%
df_november.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 116 entries, 0 to 149
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tanggal   116 non-null    object
#  1   stasiun   116 non-null    object
#  2   pm10      116 non-null    object
#  3   pm25      116 non-null    object
#  4   so2       116 non-null    object
#  5   co        116 non-null    object
#  6   o3        116 non-null    object
#  7   no2       116 non-null    object
#  8   max       116 non-null    int64
#  9   critical  116 non-null    object
#  10  categori  116 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 10.9+ KB

# %%
df_november['tanggal'] = pd.to_datetime(df_november['tanggal'])

# %%
df_november = df_november.astype({'pm10':int, 'pm25':int, 'so2':int, 'co':int, 'o3':int, 'no2':int})

# %% [markdown]
# #### Duplikat data

# %%
df_november[df_november.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tanggal, stasiun, pm10, pm25, so2, co, o3, no2, max, critical, categori]
# Index: []

# %% [markdown]
# ### Desember

# %%
df_desember = pd.read_csv('/home/yann/Documents/MSIB/Data Engineering Academy/8. Final Project/data/open_data_jakarta/indeks-standar-pencemar-udara-di-spku-bulan-desember-tahun-2021.csv')
df_desember.sample(20)
# Out:
#         tanggal                           stasiun pm10 pm25 so2  co   o3 no2  \
# 133  2021-12-10  DKI5 (Kebon Jeruk) Jakarta Barat   48   63  32   8   28  30
# 77   2021-12-16                  DKI3 (Jagakarsa)   47   68  43  11  ---  15
# 147  2021-12-24  DKI5 (Kebon Jeruk) Jakarta Barat   32   59  25   9   19  52
# 87   2021-12-26                  DKI3 (Jagakarsa)   39   59  33  14   36  12
# 154  2021-12-31  DKI5 (Kebon Jeruk) Jakarta Barat   60   87  28  19   30  53
# 66   2021-12-05                  DKI3 (Jagakarsa)   51   66  43  15   27  12
# 23   2021-12-24                DKI1 (Bunderan HI)   34   52  53  15   17  11
# 26   2021-12-27                DKI1 (Bunderan HI)   52   71  61  15   20  15
# 102  2021-12-10               DKI4 (Lubang Buaya)   45   73  42  10   24  19
# 122  2021-12-30               DKI4 (Lubang Buaya)   60  102  38  17  ---  21
# 42   2021-12-12              DKI2 (Kelapa Gading)   49   62  40  13   42  22
# ...

# %% [markdown]
# #### Missing Value

# %%
df_desember.isna().sum()
# Out:
# tanggal     0
# stasiun     0
# pm10        0
# pm25        0
# so2         0
# co          0
# o3          0
# no2         0
# max         0
# critical    3
# categori    1
# dtype: int64

# %%
df_desember = df_desember.replace('---', pd.NA)
df_desember.dropna(inplace=True)

# %% [markdown]
# #### Format tipe data

# %%
df_desember.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 128 entries, 0 to 154
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tanggal   128 non-null    object
#  1   stasiun   128 non-null    object
#  2   pm10      128 non-null    object
#  3   pm25      128 non-null    object
#  4   so2       128 non-null    object
#  5   co        128 non-null    object
#  6   o3        128 non-null    object
#  7   no2       128 non-null    object
#  8   max       128 non-null    object
#  9   critical  128 non-null    object
#  10  categori  128 non-null    object
# dtypes: object(11)
# memory usage: 12.0+ KB

# %%
df_desember['tanggal'] = pd.to_datetime(df_desember['tanggal'])

# %%
df_desember = df_desember.astype({'pm10':int, 'pm25':int, 'so2':int, 'co':int, 'o3':int, 'no2':int, 'max':int})

# %% [markdown]
# #### Duplikat data

# %%
df_desember[df_desember.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tanggal, stasiun, pm10, pm25, so2, co, o3, no2, max, critical, categori]
# Index: []

# %% [markdown]
# ### Merge All Data

# %%
df_2021 = pd.concat([df_januari,df_februari,df_maret,df_april,df_mei,df_juni,df_juli,df_agustus,df_september,df_oktober,df_november,df_desember], ignore_index=True)
df_2021
# Out:
#         tanggal                           stasiun  pm10  pm25  so2  co  o3  \
# 0    2021-01-01                DKI1 (Bunderan HI)    38    53   29   6  31
# 1    2021-01-02                DKI1 (Bunderan HI)    27    46   27   7  47
# 2    2021-01-03                DKI1 (Bunderan HI)    44    58   25   7  40
# 3    2021-01-04                DKI1 (Bunderan HI)    30    48   24   4  32
# 4    2021-01-05                DKI1 (Bunderan HI)    38    53   24   6  31
# ...         ...                               ...   ...   ...  ...  ..  ..
# 1512 2021-12-27  DKI5 (Kebon Jeruk) Jakarta Barat    54    76   36  14  21
# 1513 2021-12-28  DKI5 (Kebon Jeruk) Jakarta Barat    44    68   20  11  21
# 1514 2021-12-29  DKI5 (Kebon Jeruk) Jakarta Barat    34    54   28   8  25
# 1515 2021-12-30  DKI5 (Kebon Jeruk) Jakarta Barat    53    75   25  15  23
# 1516 2021-12-31  DKI5 (Kebon Jeruk) Jakarta Barat    60    87   28  19  30
#
#       no2  max critical categori
# 0      13   53     PM25   SEDANG
# ...

# %%
df_2021.isna().sum()
# Out:
# tanggal     0
# stasiun     0
# pm10        0
# pm25        0
# so2         0
# co          0
# o3          0
# no2         0
# max         0
# critical    0
# categori    0
# dtype: int64

# %%
df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1517 entries, 0 to 1516
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tanggal   1517 non-null   datetime64[ns]
#  1   stasiun   1517 non-null   object
#  2   pm10      1517 non-null   int64
#  3   pm25      1517 non-null   int64
#  4   so2       1517 non-null   int64
#  5   co        1517 non-null   int64
#  6   o3        1517 non-null   int64
#  7   no2       1517 non-null   int64
#  8   max       1517 non-null   int64
#  9   critical  1517 non-null   object
#  10  categori  1517 non-null   object
# dtypes: datetime64[ns](1), int64(7), object(3)
# memory usage: 130.5+ KB

# %%
# df.to_csv('data_polusi_udara_jakarta.csv', index=False)

# %% [markdown]
# ### 2015

# %%
df_2015 = pd.read_csv('/home/yann/Documents/MSIB/Data Engineering Academy/8. Final Project/indeks-standar-pencemar-udara-di-spku-2015.csv')
df_2015
# Out:
#       2015-01-01  DKI1 (Bunderan HI)  49.0   7.0  18.0  26.0  10.0  49.0.1  \
# 0     2015-01-02  DKI1 (Bunderan HI)  25.0   7.0  10.0  25.0  10.0    25.0
# 1     2015-01-03  DKI1 (Bunderan HI)  27.0   6.0  12.0  36.0  10.0    36.0
# 2     2015-01-04  DKI1 (Bunderan HI)  22.0   5.0  10.0  38.0  12.0    38.0
# 3     2015-01-05  DKI1 (Bunderan HI)  21.0   5.0   8.0  27.0   7.0    27.0
# 4     2015-01-06  DKI1 (Bunderan HI)  29.0   7.0  11.0  27.0  11.0    29.0
# ...          ...                 ...   ...   ...   ...   ...   ...     ...
# 1437  2015-12-23  DKI5 (Kebon Jeruk)  34.0  11.0  10.0  25.0   3.0    34.0
# 1438  2015-12-24  DKI5 (Kebon Jeruk)  44.0  11.0  11.0  23.0   3.0    44.0
# 1439  2015-12-25  DKI5 (Kebon Jeruk)  41.0  13.0   8.0  38.0   4.0    41.0
# 1440  2015-12-27  DKI5 (Kebon Jeruk)  53.0  11.0  14.0  46.0   5.0    53.0
# 1441  2015-12-28  DKI5 (Kebon Jeruk)  55.0  12.0  10.0  36.0   7.0    55.0
#
#       PM10    BAIK
# 0     PM10    BAIK
# 1       O3    BAIK
# ...

# %% [markdown]
# ### 2014

# %%
df_2014 = pd.read_csv('/home/yann/Documents/MSIB/Data Engineering Academy/8. Final Project/indeks-standar-pencemar-udara-di-spku-2014.csv', delimiter=';')
df_2014
# Out:
#          Tanggal             Stasiun PM10 SO2  CO  O3 NO2  MAX CRITICAL  \
# 0     2014-01-01  DKI1 (Bunderan HI)   77   3  39  54  13   77     PM10
# 1     2014-01-02  DKI1 (Bunderan HI)   55   4  29  58  12   58       O3
# 2     2014-01-03  DKI1 (Bunderan HI)   60   5  40  68  13   68       O3
# 3     2014-01-04  DKI1 (Bunderan HI)   55   7  30  56  14   56       O3
# 4     2014-01-05  DKI1 (Bunderan HI)   39   4  18  48  10   48       O3
# ...          ...                 ...  ...  ..  ..  ..  ..  ...      ...
# 1820  2014-12-27  DKI5 (Kebon Jeruk)   16   3  10   3   8   16     PM10
# 1821  2014-12-28  DKI5 (Kebon Jeruk)   19   3  24   3   9   24       CO
# 1822  2014-12-29  DKI5 (Kebon Jeruk)   11   3   8   3   3   11     PM10
# 1823  2014-12-30  DKI5 (Kebon Jeruk)   18   3   8   3   4   18     PM10
# 1824  2014-12-31  DKI5 (Kebon Jeruk)   14   3   5   3   2   14     PM10
#
#      CATEGORY
# 0      SEDANG
# 1      SEDANG
# 2      SEDANG
# 3      SEDANG
# 4        BAIK
# ...
